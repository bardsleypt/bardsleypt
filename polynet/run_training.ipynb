# %%
import os
import sys
import yaml
from collections import OrderedDict
from source.utils.logger import Logger, log_dict
from source.utils.wrappers import setup_data, train_model, calibrate_model, test_model
logger = Logger().get_logger()
# Out:
# 2022-07-25 19:27:11.751682: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-25 19:27:11.751702: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
def validate_config(conf):
    if 'data_opts' in conf:
        # Append data_dir to paths
        data_dir = conf['global_opts']['data_dir']
        if not os.path.exists(data_dir):
            os.makedirs(data_dir)
        for ds_name, ds_config in conf['data_opts']['datasets'].items():
            if os.path.dirname(ds_config['filename']) != data_dir:
                conf['data_opts']['datasets'][ds_name]['filename'] = \
                    os.path.join(data_dir, ds_config['filename'])

    if 'classif_opts' in conf:
        assert 'datasets' in conf['classif_opts'], 'datasets for train and valid must be ' \
                                               'specified in classif_opts'
        # Append data_dir to paths
        data_dir = conf['global_opts']['data_dir']
        if not os.path.exists(data_dir):
            os.makedirs(data_dir)
        for ds_name, ds_config, in conf['classif_opts']['datasets'].items():
            if os.path.dirname(ds_config['filename']) != data_dir:
                conf['classif_opts']['datasets'][ds_name]['filename'] = \
                    os.path.join(data_dir, ds_config['filename'])

    if 'calib_opts' in conf:
        assert 'datasets' in conf['classif_opts'], 'datasets for calibration must be ' \
                                               'specified in calib_opts'
        # Append data_dir to paths
        data_dir = conf['global_opts']['data_dir']
        if not os.path.exists(data_dir):
            os.makedirs(data_dir)
        for ds_name, ds_config, in conf['calib_opts']['datasets'].items():
            if os.path.dirname(ds_config['filename']) != data_dir:
                conf['calib_opts']['datasets'][ds_name]['filename'] = \
                    os.path.join(data_dir, ds_config['filename'])

    return conf

# %%
with open('training_config.yaml', 'rb') as fin:
    config = yaml.load(fin, yaml.FullLoader)

# %%
# Setup logger
logger = Logger(output_dir=os.path.join(config['global_opts']['results_dir'], 'logs'),
                c_level=config['logging_opts']['console_level'],
                f_level=config['logging_opts']['file_level'])

# %%
logger.info('Validating config')
config = validate_config(config)
log_dict(config)
# Out:
# 2022-07-25 19:27:12 - INFO   - 2578880424 - Validating config

# %%
# Setup function calls for each step
steps = OrderedDict((
    ('setup_data', lambda: setup_data(config)),
    ('train_model', lambda: train_model(config)),
    ('calibrate_model', lambda: calibrate_model(config)),
    ('test_model', lambda: test_model(config))
))

# %%
for step, fct in steps.items():
    try:
        logger.info('Running step: {}'.format(step))
        fct()
    except Exception as exc:
        logger.error(e)
        raise exc
# Out:
# 2022-07-25 19:27:13 - INFO   - 3646807458 - Running step: setup_data
# 2022-07-25 19:27:13 - INFO   - wrappers   - Setting up dataset train_data
# 2022-07-25 19:27:14 - INFO   - wrappers   - Setting up dataset valid_data
# 2022-07-25 19:27:15 - INFO   - wrappers   - setup_data took 0:00:02
# 2022-07-25 19:27:15 - INFO   - 3646807458 - Running step: train_model
# 2022-07-25 19:27:15 - INFO   - trainer    - Setting random seed: 42
# 2022-07-25 19:27:15 - INFO   - trainer    - Setting model: DerivNet
# 2022-07-25 19:27:15.209187: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-07-25 19:27:15.209209: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-07-25 19:27:15.209227: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DS1OBS): /proc/driver/nvidia/version does not exist
# 2022-07-25 19:27:15.209420: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-25 19:27:15 - INFO   - trainer    - Setting optimizer: adam
# 2022-07-25 19:27:15 - INFO   - trainer    - Setting loss function: CrossEnt
# 2022-07-25 19:27:15 - INFO   - layer_utils - Model: "DerivNet"
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - Layer (type)                    Output Shape         Param #     Connected to
# 2022-07-25 19:27:15 - INFO   - layer_utils - ==================================================================================================
# 2022-07-25 19:27:15 - INFO   - layer_utils - input (InputLayer)              [(None, 50, 1)]      0
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - mvn (MVN)                       (None, 50, 1)        202         input[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - pad (Pad1D)                     (None, 65, 1)        0           mvn[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - deriv_1 (GaussFilter)           (None, 50, 1)        18          pad[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - deriv_2 (GaussFilter)           (None, 50, 1)        18          pad[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - maxpool_1 (MaxPooling1D)        (None, 12, 1)        0           deriv_1[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - maxpool_2 (MaxPooling1D)        (None, 12, 1)        0           deriv_2[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - concat (Concatenate)            (None, 24, 1)        0           maxpool_1[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils -                                                                  maxpool_2[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - reshape (Reshape)               (None, 24)           0           concat[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - dense0 (Dense)                  (None, 20)           500         reshape[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - act_fn0 (PReLU)                 (None, 20)           1           dense0[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - dense1 (Dense)                  (None, 10)           210         act_fn0[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - act_fn1 (PReLU)                 (None, 10)           1           dense1[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - dense2 (Dense)                  (None, 5)            55          act_fn1[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - act_fn2 (PReLU)                 (None, 5)            1           dense2[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - layer_utils - output (Dense)                  (None, 3)            15          act_fn2[0][0]
# 2022-07-25 19:27:15 - INFO   - layer_utils - ==================================================================================================
# 2022-07-25 19:27:15 - INFO   - layer_utils - Total params: 1,021
# 2022-07-25 19:27:15 - INFO   - layer_utils - Trainable params: 787
# 2022-07-25 19:27:15 - INFO   - layer_utils - Non-trainable params: 234
# 2022-07-25 19:27:15 - INFO   - layer_utils - __________________________________________________________________________________________________
# 2022-07-25 19:27:15 - INFO   - trainer    - loading dataset train_df
# 2022-07-25 19:27:15 - INFO   - utils      - Loading data/train_data.pkl.gz
# 2022-07-25 19:27:15 - INFO   - utils      - Loaded data: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:16 - INFO   - utils      - 0 features contain nan values
# 2022-07-25 19:27:16 - INFO   - utils      - After removing nans: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:16 - INFO   - utils      - Renamed {features: features, label: label}
# 2022-07-25 19:27:16 - INFO   - utils      - OneHotEncoding: [1. 0. 0.] (linear class), [0. 1. 0.] (quadratic class), [0. 0. 1.] (cubic class)
# 2022-07-25 19:27:16 - INFO   - trainer    - loading dataset valid_df
# 2022-07-25 19:27:16 - INFO   - utils      - Loading data/valid_data.pkl.gz
# 2022-07-25 19:27:16 - INFO   - utils      - Loaded data: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:16 - INFO   - utils      - 0 features contain nan values
# 2022-07-25 19:27:16 - INFO   - utils      - After removing nans: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:16 - INFO   - utils      - Renamed {features: features, label: label}
# 2022-07-25 19:27:16 - INFO   - utils      - OneHotEncoding: [1. 0. 0.] (linear class), [0. 1. 0.] (quadratic class), [0. 0. 1.] (cubic class)
# 2022-07-25 19:27:16 - INFO   - trainer    - Instantiating training DataGenerator
# 2022-07-25 19:27:16 - INFO   - trainer    - Instantiating validation DataGenerator: train
# 2022-07-25 19:27:17 - INFO   - trainer    - Instantiating validation DataGenerator: valid
# 2022-07-25 19:27:17 - INFO   - trainer    - Updating mvn
# 2022-07-25 19:27:17.204089: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 29/29 [==============================] - 0s 6ms/step - loss: 1.0922
# 2022-07-25 19:27:17 - INFO   - trainer    - MVN updated with 29696.0 samples, disabling updates for layer mvn
# Epoch 1/20
# 29/29 [==============================] - 3s 10ms/step - loss: 1.0860
# 2022-07-25 19:27:20 - INFO   - metrics    - 	train_loss: 1.0789	valid_loss: 1.0773
# 2022-07-25 19:27:21 - INFO   - metrics    - 	train_prec: 0.5670	train_rec: 0.6676
# 2022-07-25 19:27:21 - INFO   - metrics    - 	valid_prec: 0.5558	valid_rec: 0.6667
# /home/patrick/projects/bardsleypt.git/polynet/source/utils/metrics.py:176: RuntimeWarning: invalid value encountered in long_scalars
#   prec_[lab] = np.nan_to_num(np.sum(preds_[pos_idx] == lab) /
# Epoch 2/20
# 29/29 [==============================] - 0s 11ms/step - loss: 1.0692
# 2022-07-25 19:27:22 - INFO   - metrics    - 	train_loss: 1.0570	valid_loss: 1.0546
# 2022-07-25 19:27:22 - INFO   - metrics    - 	train_prec: 0.5793	train_rec: 0.6696
# 2022-07-25 19:27:22 - INFO   - metrics    - 	valid_prec: 0.5973	valid_rec: 0.6668
# Epoch 3/20
# 29/29 [==============================] - 0s 11ms/step - loss: 1.0411
# 2022-07-25 19:27:23 - INFO   - metrics    - 	train_loss: 1.0218	valid_loss: 1.0192
# 2022-07-25 19:27:23 - INFO   - metrics    - 	train_prec: 0.5556	train_rec: 0.6667
# 2022-07-25 19:27:23 - INFO   - metrics    - 	valid_prec: 0.5556	valid_rec: 0.6667
# Epoch 4/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.9988
# 2022-07-25 19:27:24 - INFO   - metrics    - 	train_loss: 0.9718	valid_loss: 0.9679
# 2022-07-25 19:27:24 - INFO   - metrics    - 	train_prec: 0.5556	train_rec: 0.6667
# 2022-07-25 19:27:24 - INFO   - metrics    - 	valid_prec: 0.5556	valid_rec: 0.6667
# Epoch 5/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.9417
# 2022-07-25 19:27:25 - INFO   - metrics    - 	train_loss: 0.9071	valid_loss: 0.9000
# 2022-07-25 19:27:25 - INFO   - metrics    - 	train_prec: 0.5556	train_rec: 0.6667
# 2022-07-25 19:27:26 - INFO   - metrics    - 	valid_prec: 0.5556	valid_rec: 0.6667
# Epoch 6/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.8720
# 2022-07-25 19:27:26 - INFO   - metrics    - 	train_loss: 0.8367	valid_loss: 0.8280
# 2022-07-25 19:27:27 - INFO   - metrics    - 	train_prec: 0.5556	train_rec: 0.6667
# 2022-07-25 19:27:27 - INFO   - metrics    - 	valid_prec: 0.5556	valid_rec: 0.6667
# Epoch 7/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.8063
# 2022-07-25 19:27:28 - INFO   - metrics    - 	train_loss: 0.7765	valid_loss: 0.7667
# 2022-07-25 19:27:28 - INFO   - metrics    - 	train_prec: 0.5556	train_rec: 0.6667
# 2022-07-25 19:27:28 - INFO   - metrics    - 	valid_prec: 0.5556	valid_rec: 0.6667
# Epoch 8/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.7514
# 2022-07-25 19:27:29 - INFO   - metrics    - 	train_loss: 0.7255	valid_loss: 0.7149
# 2022-07-25 19:27:29 - INFO   - metrics    - 	train_prec: 0.7073	train_rec: 0.7942
# 2022-07-25 19:27:29 - INFO   - metrics    - 	valid_prec: 0.7440	valid_rec: 0.8285
# Epoch 9/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.7023
# 2022-07-25 19:27:30 - INFO   - metrics    - 	train_loss: 0.6761	valid_loss: 0.6652
# 2022-07-25 19:27:30 - INFO   - metrics    - 	train_prec: 0.7275	train_rec: 0.8140
# 2022-07-25 19:27:30 - INFO   - metrics    - 	valid_prec: 0.7495	valid_rec: 0.8330
# Epoch 10/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6465
# 2022-07-25 19:27:31 - INFO   - metrics    - 	train_loss: 0.6119	valid_loss: 0.6064
# 2022-07-25 19:27:31 - INFO   - metrics    - 	train_prec: 0.9290	train_rec: 0.8876
# 2022-07-25 19:27:32 - INFO   - metrics    - 	valid_prec: 0.9363	valid_rec: 0.8968
# Epoch 11/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.5675
# 2022-07-25 19:27:32 - INFO   - metrics    - 	train_loss: 0.5134	valid_loss: 0.5127
# 2022-07-25 19:27:33 - INFO   - metrics    - 	train_prec: 0.9797	train_rec: 0.9772
# 2022-07-25 19:27:33 - INFO   - metrics    - 	valid_prec: 0.9998	valid_rec: 0.9998
# Epoch 12/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.4494
# 2022-07-25 19:27:33 - INFO   - metrics    - 	train_loss: 0.3780	valid_loss: 0.3710
# 2022-07-25 19:27:34 - INFO   - metrics    - 	train_prec: 0.9865	train_rec: 0.9854
# 2022-07-25 19:27:34 - INFO   - metrics    - 	valid_prec: 1.0000	valid_rec: 1.0000
# Epoch 13/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3139
# 2022-07-25 19:27:35 - INFO   - metrics    - 	train_loss: 0.2524	valid_loss: 0.2425
# 2022-07-25 19:27:35 - INFO   - metrics    - 	train_prec: 0.9973	train_rec: 0.9973
# 2022-07-25 19:27:35 - INFO   - metrics    - 	valid_prec: 1.0000	valid_rec: 1.0000
# Epoch 14/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2120
# 2022-07-25 19:27:36 - INFO   - metrics    - 	train_loss: 0.1765	valid_loss: 0.1564
# 2022-07-25 19:27:36 - INFO   - metrics    - 	train_prec: 0.9979	train_rec: 0.9979
# 2022-07-25 19:27:36 - INFO   - metrics    - 	valid_prec: 1.0000	valid_rec: 1.0000
# Epoch 15/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1513
# 2022-07-25 19:27:37 - INFO   - metrics    - 	train_loss: 0.1283	valid_loss: 0.1096
# 2022-07-25 19:27:37 - INFO   - metrics    - 	train_prec: 0.9985	train_rec: 0.9985
# 2022-07-25 19:27:37 - INFO   - metrics    - 	valid_prec: 1.0000	valid_rec: 1.0000
# Epoch 16/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1113
# 2022-07-25 19:27:38 - INFO   - metrics    - 	train_loss: 0.0954	valid_loss: 0.0772
# 2022-07-25 19:27:38 - INFO   - metrics    - 	train_prec: 0.9988	train_rec: 0.9988
# 2022-07-25 19:27:39 - INFO   - metrics    - 	valid_prec: 1.0000	valid_rec: 1.0000
# Epoch 17/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0837
# 2022-07-25 19:27:39 - INFO   - metrics    - 	train_loss: 0.0729	valid_loss: 0.0565
# 2022-07-25 19:27:40 - INFO   - metrics    - 	train_prec: 0.9989	train_rec: 0.9988
# 2022-07-25 19:27:40 - INFO   - metrics    - 	valid_prec: 1.0000	valid_rec: 1.0000
# Epoch 18/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0648
# 2022-07-25 19:27:41 - INFO   - metrics    - 	train_loss: 0.0572	valid_loss: 0.0422
# 2022-07-25 19:27:41 - INFO   - metrics    - 	train_prec: 0.9989	train_rec: 0.9989
# 2022-07-25 19:27:41 - INFO   - metrics    - 	valid_prec: 1.0000	valid_rec: 1.0000
# Epoch 19/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0515
# 2022-07-25 19:27:42 - INFO   - metrics    - 	train_loss: 0.0461	valid_loss: 0.0303
# 2022-07-25 19:27:42 - INFO   - metrics    - 	train_prec: 0.9991	train_rec: 0.9991
# 2022-07-25 19:27:42 - INFO   - metrics    - 	valid_prec: 1.0000	valid_rec: 1.0000
# Epoch 20/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0419
# 2022-07-25 19:27:43 - INFO   - metrics    - 	train_loss: 0.0379	valid_loss: 0.0234
# 2022-07-25 19:27:43 - INFO   - metrics    - 	train_prec: 0.9991	train_rec: 0.9991
# 2022-07-25 19:27:43 - INFO   - metrics    - 	valid_prec: 1.0000	valid_rec: 1.0000
# 2022-07-25 19:27:43 - INFO   - wrappers   - train_model took 0:00:28
# 2022-07-25 19:27:43 - INFO   - 3646807458 - Running step: calibrate_model
# 2022-07-25 19:27:43 - INFO   - wrappers   - (Re)instantiating DerivNet model
# 2022-07-25 19:27:44 - INFO   - wrappers   - Loading model weights from results/models/best_valid_loss.h5
# 2022-07-25 19:27:44 - INFO   - utils      - Loading data/train_data.pkl.gz
# 2022-07-25 19:27:44 - INFO   - utils      - Loaded data: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:44 - INFO   - utils      - 0 features contain nan values
# 2022-07-25 19:27:44 - INFO   - utils      - After removing nans: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:44 - INFO   - utils      - Renamed {features: features, label: label}
# 2022-07-25 19:27:44 - INFO   - utils      - OneHotEncoding: [1. 0. 0.] (linear class), [0. 1. 0.] (quadratic class), [0. 0. 1.] (cubic class)
# 2022-07-25 19:27:44 - INFO   - utils      - Loading data/valid_data.pkl.gz
# 2022-07-25 19:27:44 - INFO   - utils      - Loaded data: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:45 - INFO   - utils      - 0 features contain nan values
# 2022-07-25 19:27:45 - INFO   - utils      - After removing nans: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:45 - INFO   - utils      - Renamed {features: features, label: label}
# 2022-07-25 19:27:45 - INFO   - utils      - OneHotEncoding: [1. 0. 0.] (linear class), [0. 1. 0.] (quadratic class), [0. 0. 1.] (cubic class)
# 2022-07-25 19:27:45 - INFO   - wrappers   - calibrate_model took 0:00:02
# 2022-07-25 19:27:45 - INFO   - 3646807458 - Running step: test_model
# 2022-07-25 19:27:45 - INFO   - wrappers   - (Re)instantiating calib model
# 2022-07-25 19:27:45 - INFO   - wrappers   - Loading model weights from results/models/cal_model.h5
# 2022-07-25 19:27:45 - INFO   - wrappers   - loading dataset train_df
# 2022-07-25 19:27:45 - INFO   - utils      - Loading data/train_data.pkl.gz
# 2022-07-25 19:27:45 - INFO   - utils      - Loaded data: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:45 - INFO   - utils      - 0 features contain nan values
# 2022-07-25 19:27:45 - INFO   - utils      - After removing nans: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:45 - INFO   - utils      - Renamed {features: features, label: label}
# 2022-07-25 19:27:45 - INFO   - utils      - OneHotEncoding: [1. 0. 0.] (linear class), [0. 1. 0.] (quadratic class), [0. 0. 1.] (cubic class)
# 2022-07-25 19:27:45 - INFO   - utils      - Loading data/train_data.pkl.gz
# 2022-07-25 19:27:46 - INFO   - utils      - Loaded data: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:46 - INFO   - utils      - 0 features contain nan values
# 2022-07-25 19:27:46 - INFO   - utils      - After removing nans: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:46 - INFO   - utils      - Renamed {features: features, label: label}
# 2022-07-25 19:27:46 - INFO   - utils      - OneHotEncoding: [1. 0. 0.] (linear class), [0. 1. 0.] (quadratic class), [0. 0. 1.] (cubic class)
# 2022-07-25 19:27:48 - INFO   - wrappers   - loading dataset valid_df
# 2022-07-25 19:27:48 - INFO   - utils      - Loading data/valid_data.pkl.gz
# 2022-07-25 19:27:48 - INFO   - utils      - Loaded data: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:48 - INFO   - utils      - 0 features contain nan values
# 2022-07-25 19:27:48 - INFO   - utils      - After removing nans: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:48 - INFO   - utils      - Renamed {features: features, label: label}
# 2022-07-25 19:27:48 - INFO   - utils      - OneHotEncoding: [1. 0. 0.] (linear class), [0. 1. 0.] (quadratic class), [0. 0. 1.] (cubic class)
# 2022-07-25 19:27:48 - INFO   - utils      - Loading data/valid_data.pkl.gz
# 2022-07-25 19:27:48 - INFO   - utils      - Loaded data: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:48 - INFO   - utils      - 0 features contain nan values
# 2022-07-25 19:27:48 - INFO   - utils      - After removing nans: 10000 (linear class), 10000 (quadratic class), 10000 (cubic class)
# 2022-07-25 19:27:48 - INFO   - utils      - Renamed {features: features, label: label}
# 2022-07-25 19:27:48 - INFO   - utils      - OneHotEncoding: [1. 0. 0.] (linear class), [0. 1. 0.] (quadratic class), [0. 0. 1.] (cubic class)
# 2022-07-25 19:27:50 - INFO   - wrappers   - Test Metrics:
#            prec       rec
# train  0.999134  0.999133
# valid  1.000000  1.000000
